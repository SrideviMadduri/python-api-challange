# %%
import gmaps
import pandas as pd

# Google developer API key
from api_keys import gkey

# %%
print(gkey)
# Out:
# AIzaSyDHJ2uAeCHE5sgrFlvtl4BtvGJTIU9K-pQ

# %%
cities_df = pd.read_csv('output_data/cities.csv', index_col=0)
cities_df
# Out:
#               City  Lattitude  Longitude  Temperature  Humidity  Cloudiness  \
# 0    mar del plata   -38.0023   -57.5575        62.73        89          75
# 1             bara    10.3744    10.7288        76.24        42          70
# 2        geraldton   -28.7667   114.6000        62.49        86          45
# 3             kosa    59.9445    54.9977        31.23        83          55
# 4   saint-philippe   -21.3585    55.7679        69.39        79          43
# ..             ...        ...        ...          ...       ...         ...
# 87     thaba-tseka   -29.5220    28.6084        51.89        87         100
# 88          lompoc    34.6391  -120.4579        78.62        51           0
# 89            poso    -1.3959   120.7524        76.91        83          72
# 90     east london   -33.0153    27.9116        66.92        81          93
# 91       cape town   -33.9258    18.4232        60.94        77           0
#
#     Wind Speed
# 0        14.97
# 1         1.63
# ...

# %%
# Configure gmaps with API key
gmaps.configure(api_key=gkey)

# %%
 #Store 'Lat' and 'Lng' into  locations 
locations = cities_df[["Lattitude", "Longitude"]].astype(float)

# Convert Poverty Rate to float and store
# HINT: be sure to handle NaN values
#cities_df = cities_df.dropna()
humidity = cities_df["Humidity"].astype(float)

# %%
# Create a poverty Heatmap layer

fig = gmaps.figure(center=(0,0), zoom_level=2)
#gmaps.figure()

heat_layer = gmaps.heatmap_layer(locations, 
                                 weights=humidity, 
                                 dissipating=False, max_intensity=100,
                                 point_radius = 5
                                 
                                )

fig.add_layer(heat_layer)

fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
#Narrow down the DataFrame to find your ideal weather condition. For example:
#  * A max temperature lower than 80 degrees but higher than 70.
#  * Wind speed less than 10 mph.
 # * Zero cloudiness.


ideal_weather_df =cities_df[(cities_df['Temperature'] > 60) & (cities_df['Temperature']<80)
                            & ((cities_df['Wind Speed']<10)) & (cities_df['Cloudiness']==0)] 

ideal_weather_df
# Out:
#                 City  Lattitude  Longitude  Temperature  Humidity  Cloudiness  \
# 24          katsuura    35.1333   140.3000        63.84        62           0
# 55  tando ghulam ali    25.1311    68.8676        75.87        62           0
# 56              siva    29.2041    25.5195        71.38        39           0
# 73         mount isa   -20.7333   139.5000        77.00        38           0
# 86          vallenar   -28.5708   -70.7581        75.65        23           0
#
#     Wind Speed
# 24        5.01
# 55        7.31
# 56        5.46
# 73        8.66
# 86        6.38

# %%
bank_layer = gmaps.symbol_layer(
    locations, fill_color='rgba(0, 150, 0, 0.4)',
    stroke_color='rgba(0, 0, 150, 0.4)', scale=2,
    info_box_content=[f"<h3>Bank amount:</h3> {bank}</br>Sudeep" for bank in range(locations.shape[0])]
    #info_box_content=['a','b']
    #hover_text=['x' for x in range(locations.shape[0])]
)


fig = gmaps.figure()
fig.add_layer(bank_layer)

fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
